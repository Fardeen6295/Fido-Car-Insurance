# %%
# %sql
CREATE CATALOG IF NOT EXISTS smart_claims_dev 
MANAGED LOCATION 'abfss://metastore@fidodl.dfs.core.windows.net/smart_claims_dev'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS smart_claims_dev.00_landing
MANAGED LOCATION 'abfss://metastore@fidodl.dfs.core.windows.net/smart_claims_dev/landing'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS smart_claims_dev.01_bronze
MANAGED LOCATION 'abfss://metastore@fidodl.dfs.core.windows.net/smart_claims_dev/bronze'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS smart_claims_dev.02_silver
MANAGED LOCATION 'abfss://metastore@fidodl.dfs.core.windows.net/smart_claims_dev/silver'

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS smart_claims_dev.03_gold
MANAGED LOCATION 'abfss://metastore@fidodl.dfs.core.windows.net/smart_claims_dev/gold'

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS smart_claims_dev.00_landing.tele_data
LOCATION 'abfss://landing@fidodl.dfs.core.windows.net/telematics-data'

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS smart_claims_dev.00_landing.training_images
LOCATION 'abfss://landing@fidodl.dfs.core.windows.net/training-data'

# %%
# %sql
CREATE EXTERNAL VOLUME IF NOT EXISTS smart_claims_dev.00_landing.claims
LOCATION 'abfss://landing@fidodl.dfs.core.windows.net/claims'
